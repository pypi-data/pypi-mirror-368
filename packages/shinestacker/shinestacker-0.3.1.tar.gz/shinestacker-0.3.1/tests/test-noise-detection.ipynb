# %%
# %run -i "test_0020_noise_detection.py"
# Out:
# [INF] noise-map: map noisy pixels, frames in folder: ./img-noise
# noise-map:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] noise-map: hot pixels: rgb: 36, r: 35, g: 5, b: 7
# [INF] noise-map: elapsed time: 00:00:00.38s
# [INF] noise-map: completed
# [INF] job: elapsed time: 00:00:00.38s
# [INF] job: completed
# [INF] img-noise-corr: begin run
# [INF] img-noise-corr: : 6 files in folder: ./img-jpg
# img-noise-corr:   0%|          | 0/6 [00:00<?, ?it/s]
# [INF] img-noise-corr: elapsed time: 00:00:00.38s                              rite output image
# [INF] img-noise-corr: completed
# [INF] job: elapsed time: 00:00:00.38s
# [INF] job: completed
